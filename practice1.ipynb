# %% [markdown]
# <a href="https://colab.research.google.com/github/MissingSemesterCUET/ML/blob/main/practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rules
# - Do not change the function signature (name and parameters). Otherwise, the grader will not work.

# %%
# Do not use any library functions
def squares_from_1_to_n(n):
    ...

# %%
# Do not use any library functions
def count_frequencies(lst):
    ...

# %%
# Do not use any library functions
# The input lists are of equal length
def dot_product(a, b):
    ...

# %%
# Do not use any library functions
def transpose_matrix(a):
    ...

# %%
# Do not use any library functions
def matrix_multiplication(a, b):
    ...

# %%
# Do not use any library functions
def linspace(start, end, num):
    ...

# %%
import torch

def compute_gradient(x_val):
    # Define x as a tensor with requires_grad=True
    # Compute y = x^2 + 2x + 1
    # Compute the gradient
    # Return the gradient value as a float (use .item())
    ...

# %% [markdown]
# # Grading

# %%
import hashlib
import torch

tests = [
    lambda: squares_from_1_to_n(5),
    lambda: matrix_multiplication([[1,2], [3,4]], [[5, 6], [7, 8]]),
    lambda: linspace(1, 5, 10),
    lambda: dot_product([1, 2, 3], [4, 5, 6]),
    lambda: transpose_matrix([[1, 2, 3], [4, 5, 6]]),
    lambda: count_frequencies([1, 2, 2, 3, 3, 3]),
    lambda: compute_gradient(3.0)
]
secret_key = "CUET_ML_SECRET_KEY"
code_string = ""
for test in tests:
    try:
        code_string += str(test())
    except Exception as e:
        print("Error: ", e)

hash_code = hashlib.sha256(code_string.encode()).hexdigest()[:10]

print("YOUR SUBMISSION CODE: ", hash_code)
print("Copy this code and paste it in the Google Form!")
# Out:
# 🏆 YOUR SUBMISSION CODE: d5c4d2ebc7
# 👉 Copy this code and paste it in the Google Form!

# %% [markdown]
# CORRECT CODE: e238feb8be
