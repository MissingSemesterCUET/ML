# %% [markdown]
# <a href="https://colab.research.google.com/github/MissingSemesterCUET/ML/blob/main/lecture1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Machine Learning

# %% [markdown]
# # Python
# - Google Collab (colab.new)
#     - `CTRL + Enter` to run a cell
# - Compiler vs Interpreter
# - Dynamic vs. Static Typing
# - `print`
# - Indentation is not for style, it is the syntax.
# - `else if` →  `elif`
# - `for` loop
# - `Array` → `List`
# - `Dictionary`
# - Object multipication
# - List Comprehension

# %% [markdown]
# # Maths

# %% [markdown]
# ## Vectors
# - Vector in Physics vs Vector in Maths
# - Indexing Vectors: Vector vs Set
# - Vector Operations: Hadamard Product

# %% [markdown]
# ## Matrices
# - Shape
# - Reshape
# - Transpose
# - Matrix multiplication (code)
# - Matrix-Vector Multiplication: Both row & column
# - Tensors: Rank

# %% [markdown]
# ## Pytorch
# - Vectors & Matrices are the same
# - `zeros`, `ones`, `rand`, `randn`, `eye`, `arange`, `linspace`
# - 0D Tensors
# - slicing
# - `add` vs `add_`

# %% [markdown]
# ## Matplotlib
# - Visual Debugging
# - `scatter`
# - `plot`
# - `hist`
# - `ipywidget.interact`
