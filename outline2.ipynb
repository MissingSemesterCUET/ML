# %% [markdown]
# <a href="https://colab.research.google.com/github/MissingSemesterCUET/ML/blob/main/outline2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First steps with PyTorch: Linear Regression

# %% [markdown]
# ##
